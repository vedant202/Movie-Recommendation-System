# %%
import pandas as pd

# %%
metadata = pd.read_csv('./Movie data/movies_metadata.csv')

metadata.head()
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
from sklearn.utils import shuffle
print(metadata.columns)
print(metadata.shape)
metadata1 = shuffle(metadata)

metadata1 = metadata1[:12000]
metadata1 = metadata1.reset_index(drop=True)

metadata1.head()
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
# (45466, 24)
#    adult belongs_to_collection    budget  \
# 0  False                   NaN  62000000
# 1  False                   NaN         0
# 2  False                   NaN         0
# 3  False                   NaN         0
# 4  False                   NaN         0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                [{'id': 99, 'name': 'Documentary'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 3  [{'id': 10751, 'name': 'Family'}, {'id': 35, '...
# ...

# %%
c = metadata1['vote_average'].mean()

# %%
c
# Out:
# 5.628794066172181

# %%
metadata1[['title','vote_count']].head(10)
# Out:
#                                               title  vote_count
# 0                            The American President       199.0
# 1                                    Fantastic Lies         2.0
# 2                                Pauline & Paulette         5.0
# 3                                 Finding Christmas         9.0
# 4                                            Skippy         4.0
# 5                                     Almost Angels         1.0
# 6                                            Me Too        10.0
# 7                                An Inspector Calls        42.0
# 8                                         They Live       562.0
# 9  United States of Secrets (Part One): The Program         1.0

# %%
m = metadata1['vote_count'].quantile(0.90)
print(m)
# Out:
# 148.0

# %%
q_movies = metadata1.copy().loc[metadata1['vote_count']>=m]
q_movies.shape
# Out:
# (1202, 24)

# %%
def weighted_rating(x, c=c,m=m):
    v = x['vote_count']
    R = x['vote_average']
    
    return (v/(v+m) * R)+ (m/(m+v)*c)

# %%
metadata1.shape
# Out:
# (12000, 24)

# %%
q_movies['score'] = q_movies.apply(weighted_rating,axis=1)

# %%
q_movies = q_movies.sort_values('score',ascending=False)

# %%
q_movies[['title', 'vote_count', 'vote_average', 'score']].head(20)
# Out:
#                                                    title  vote_count  \
# 2115                                     The Dark Knight     12269.0
# 9830                                            Whiplash      4376.0
# 4319                              The Godfather: Part II      3418.0
# 8005                     One Flew Over the Cuckoo's Nest      3001.0
# 7947                                        Interstellar     11187.0
# 10389      The Lord of the Rings: The Return of the King      8226.0
# 1564                                           Star Wars      6778.0
# 8002                                  The Usual Suspects      3334.0
# 297                       The Good, the Bad and the Ugly      2371.0
# 11587                                      The Lion King      5520.0
# 5781                                            Scarface      3017.0
# 992                              Guardians of the Galaxy     10014.0
# 9969                                Inglourious Basterds      6598.0
# ...

# %%
metadata1['overview'].head(10)
# Out:
# 0    Widowed U.S. president Andrew Shepherd, one of...
# 1    “Fantastic Lies” returns to the night of March...
# 2    Pauline is a 'little girl of 66 years old'. Sh...
# 3    Single mother Ryan has just about given up on ...
# 4    Skippy, the mischievous son of a wealthy docto...
# 5    Supported avidly by his mother and more reluct...
# 6    Five passengers - the Bandit, his friend Matve...
# 7    A mysterious Inspector investigates the wealth...
# 8    Nada, a down-on-his-luck construction worker, ...
# 9    Last year Edward Snowden downloaded tens of th...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

metadata1['overview'] = metadata1['overview'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data

tfidf_matrix = tfidf.fit_transform(metadata1['overview'])

tfidf_matrix.shape
# Out:
# (12000, 39000)

# %%
#Array mapping from feature integer indices to feature name.
tfidf.get_feature_names()[5000:5010]
# Out:
# ['businessman',
#  'businessmen',
#  'businesswoman',
#  'busker',
#  'buskers',
#  'busload',
#  'busses',
#  'bussone',
#  'bussotti',
#  'bust']

# %%
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# for i in cosine_sim[2]:
#     print(i,end=" ")
cosine_sim[2]
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %%
cosine_sim.shape
# Out:
# (12000, 12000)

# %%
metadata1[['title']].head(5)
# Out:
#                     title
# 0  The American President
# 1          Fantastic Lies
# 2      Pauline & Paulette
# 3       Finding Christmas
# 4                  Skippy

# %%
#Construct a reverse map of indices and movie titles

indices = pd.Series(metadata1.index,index=metadata1.title).drop_duplicates()
indices.head(30)
# Out:
# title
# The American President                               0
# Fantastic Lies                                       1
# Pauline & Paulette                                   2
# Finding Christmas                                    3
# Skippy                                               4
# Almost Angels                                        5
# Me Too                                               6
# An Inspector Calls                                   7
# They Live                                            8
# United States of Secrets (Part One): The Program     9
# The Abdication                                      10
# 7 Women                                             11
# The Great Gatsby                                    12
# Chachi 420                                          13
# Superpower                                          14
# The Bride Goes Wild                                 15
# Room 666                                            16
# ...

# %%
def get_reccomendations(title,cosine_sim=cosine_sim,metadata1=metadata1):
    idx = indices[title]
    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]
    
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    return metadata1['title'].loc[movie_indices]

# %%
get_reccomendations('The Godfather')
#The Godfather indices['The Nativity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ...

# %%
credits = pd.read_csv('./Movie data/credits.csv')
keywords = pd.read_csv('./Movie data/keywords.csv')

# %%
metadata = metadata.drop([19730, 29503, 35587])

keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')
metadata['id'] = metadata['id'].astype('int')

# Merge keywords and credits into your main metadata dataframe
metadata = metadata.merge(credits, on='id')
metadata = metadata.merge(keywords, on='id')

# %%
metadata.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
from ast import literal_eval

features = ['cast', 'crew', 'keywords', 'genres']

for feature in features:
    metadata[feature] = metadata[feature].apply(literal_eval)

# %%
import numpy as np

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
def getList(x):
    if(isinstance(x,list)):
        names = [i['name'] for i in x]
        
        if(len(names) >3):
            names = names[:3]
            return names
    return []

# %%
metadata['director'] = metadata['crew'].apply(get_director)

features = ['cast', 'keywords', 'genres']

for feature in features:
    metadata[feature]= metadata[feature].apply(getList)

# %%
metadata[['title', 'cast', 'director', 'keywords', 'genres']].head(3)
# Out:
#               title                                            cast  \
# 0         Toy Story             [Tom Hanks, Tim Allen, Don Rickles]
# 1           Jumanji  [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2  Grumpier Old Men      [Walter Matthau, Jack Lemmon, Ann-Margret]
#
#         director                                           keywords genres
# 0  John Lasseter                               [jealousy, toy, boy]     []
# 1   Joe Johnston  [board game, disappearance, based on children'...     []
# 2  Howard Deutch       [fishing, best friend, duringcreditsstinger]     []

# %%
def clean_data(x):
    if isinstance(x,list):
        return [str.lower(i.replace(" ","")) for i in x]
    else:
        if( isinstance(x,str)):
            return str.lower(x.replace(" ",""))
        else:
            return ''

# %%
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    metadata[feature] = metadata[feature].apply(clean_data)

# %%
def create_soup(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])

# %%
metadata['soup'] = metadata.apply(create_soup,axis=1)

# %%
metadata[['soup']].head(2)
# Out:
#                                                 soup
# 0  jealousy toy boy tomhanks timallen donrickles ...
# 1  boardgame disappearance basedonchildren'sbook ...

# %%
metadata2 = shuffle(metadata)

metadata2 = metadata2[:15000]
metadata2 = metadata2.reset_index(drop=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(metadata2['soup'])

# %%
count_matrix.shape
# Out:
# (15000, 33121)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
# metadata = metadata2.reset_index()
indices = pd.Series(metadata2.index, index=metadata2['title'])

# %%
# get_recommendations('The Dark Knight Rises', cosine_sim2,metadata2)
get_reccomendations('The Dark Knight Rises', cosine_sim2,metadata2)
# Out:
# 10984             Batman Begins
# 12769                   Shaitan
# 13914                      Sara
# 14467              Certain Prey
# 7555                One Way Out
# 173      A Prayer for the Dying
# 367                  Dirty Lies
# 615                Tony Arzenta
# 632                    Thursday
# 1031            Rolling Thunder
# Name: title, dtype: object

# %%
get_reccomendations('Deadfall', cosine_sim2,metadata2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ...
